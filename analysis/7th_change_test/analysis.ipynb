# %%
import pandas as pd

# %%
df = pd.read_csv('metrics.csv')
df
# Out:
#                                               video  precision    recall  \
# 0                               Robbery102_x264.mp4   0.776374  0.995772
# 1                    VIRAT_S_000001_resized.mp4_0.1   0.833979  0.963464
# 2                          Stealing101_x264.mp4_0.0   0.739866  0.999468
# 3           Stealing112_x264.mp4_1.7000000000000002   0.980483  0.942716
# 4                               Robbery106_x264.mp4   0.921053  0.983681
# 5                              Stealing036_x264.mp4   0.922338  0.998267
# 6                              Stealing108_x264.mp4   1.000000  0.945033
# 7       VIRAT_S_000207_02_000498_000530_resized.mp4   0.952840  0.991081
# 8                              Stealing107_x264.mp4   0.969408  0.907446
# 9                               Robbery004_x264.mp4   0.796721  0.997537
# 10                         Robbery096_x264.mp4_88.5   0.130152  0.967742
# 11  VIRAT_S_050201_05_000890_000944_resized.mp4_0.1   0.703576  0.886482
# ...

# %%
df.describe()
# Out:
#        precision     recall         f1
# count  23.000000  23.000000  23.000000
# mean    0.755171   0.925803   0.813070
# std     0.264651   0.203801   0.244105
# min     0.000000   0.000000   0.000000
# 25%     0.711437   0.948739   0.814010
# 50%     0.833979   0.972599   0.894057
# 75%     0.926975   0.988922   0.950915
# max     1.000000   0.999468   0.988179
